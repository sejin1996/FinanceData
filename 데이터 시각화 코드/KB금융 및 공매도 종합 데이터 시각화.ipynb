# %%
import matplotlib.pyplot as plt
# %matplotlib inline


import pandas as pd
import numpy as np


from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
df=pd.read_csv("KB금융 공매도_금액.csv",index_col='일자')

# %%
df.head()
# Out:
#             공매도 금액(전체)  공매도 금액(잔고금액)
# 일자
# 2021-03-31   123894800  6.121135e+10
# 2021-03-30   304557200  5.034231e+10
# 2021-03-29   359094000  5.146984e+10
# 2021-03-26   864034900  5.020053e+10
# 2021-03-25   408951900  5.023190e+10

# %%
df.shape
# Out:
# (1167, 2)

# %%
df.describe()
# Out:
#          공매도 금액(전체)  공매도 금액(잔고금액)
# count  1.167000e+03  1.167000e+03
# mean   3.152910e+09  6.702982e+10
# std    3.477629e+09  3.355139e+10
# min    0.000000e+00  2.298815e+10
# 25%    4.302960e+08  4.948906e+10
# 50%    2.210159e+09  5.776562e+10
# 75%    4.667607e+09  7.580078e+10
# max    3.278692e+10  2.871210e+11

# %%
df.info
# Out:
# <bound method DataFrame.info of             공매도 금액(전체)  공매도 금액(잔고금액)
# 일자
# 2021-03-31   123894800  6.121135e+10
# 2021-03-30   304557200  5.034231e+10
# 2021-03-29   359094000  5.146984e+10
# 2021-03-26   864034900  5.020053e+10
# 2021-03-25   408951900  5.023190e+10
# ...                ...           ...
# 2016-07-06  1118667250  2.528345e+10
# 2016-07-05   231293100  2.663003e+10
# 2016-07-04   571550700  2.663003e+10
# 2016-07-01   307107550  2.666080e+10
# 2016-06-30  1952399200  2.565376e+10
#
# [1167 rows x 2 columns]>

# %%
df.index = pd.to_datetime(df.index)

fig = plt.figure(figsize=(20, 12)) # 차트 생성 및 사이즈 설정
ax = fig.add_subplot(1,1,1) # subplot 생성
ax2 = ax.twinx()


line1=ax.plot(df['공매도 금액(전체)'], label='전체금액(100억)', color='b')
line2=ax2.plot(df['공매도 금액(잔고금액)'],label='잔고금액(1000억)', color='r')


ax.set_title('KB 금융 공매도 금액과 잔고금액', fontsize=20) # 타이틀 설정
ax.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
ax.set_xlabel('Date', fontsize=14) # y1축 설정
ax2.set_ylabel('잔고금액(\)', fontsize=14)   #y2축 설정



lines= line1 + line2
labels = [l.get_label() for l in lines]
ax.legend(lines, labels, loc='best',fontsize=14)

plt.show()
# Out:
# Text(0.5, 1.0, 'KB 금융 공매도 금액과 잔고금액')
# Text(0, 0.5, '전체 거래대금(\\)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '잔고금액(\\)')

# %%
fig.savefig('KB금융 공매도 금액(시각화).png')

# %%
df1=pd.read_csv("KB금융 공매도_수량.csv",index_col='일자')

# %%
df1.head()
# Out:
#             공매도 수량(전체)  공매도 수량(잔고수량)
# 일자
# 2021-03-31        2221       1089170
# 2021-03-30        5491        916982
# 2021-03-29        6744        958470
# 2021-03-26       16247        943619
# 2021-03-25        7789        954979

# %%
df1.info
# Out:
# <bound method DataFrame.info of             공매도 수량(전체)  공매도 수량(잔고수량)
# 일자
# 2021-03-31        2221       1089170
# 2021-03-30        5491        916982
# 2021-03-29        6744        958470
# 2021-03-26       16247        943619
# 2021-03-25        7789        954979
# ...                ...           ...
# 2016-07-06       35004        793829
# 2016-07-05        7096        816872
# 2016-07-04       17494        816872
# 2016-07-01        9360        811592
# 2016-06-30       59732        786925
#
# [1167 rows x 2 columns]>

# %%
df1.describe()
# Out:
#           공매도 수량(전체)  공매도 수량(잔고수량)
# count    1167.000000  1.167000e+03
# mean    65242.110540  1.475713e+06
# std     74079.704928  8.302645e+05
# min         0.000000  6.558010e+05
# 25%      8904.500000  9.866730e+05
# 50%     45646.000000  1.182051e+06
# 75%     94470.500000  1.857584e+06
# max    832080.000000  6.803342e+06

# %%
df1.index = pd.to_datetime(df1.index)

do = plt.figure(figsize=(20, 12)) # 차트 생성 및 사이즈 설정
do1 = do.add_subplot(1,1,1) # subplot 생성
do2 = do1.twinx()


line3=do1.plot(df1['공매도 수량(전체)'], label='전체수량(10만)', color='b')
line4=do2.plot(df1['공매도 수량(잔고수량)'],label='잔고수량(100만)', color='r')


do1.set_title('KB 금융 공매도 수량과 잔고수량', fontsize=20) # 타이틀 설정
do1.set_ylabel('공매도 수량(전체)', fontsize=14) # x축 설정
do1.set_xlabel('Date', fontsize=14) # y1축 설정
do2.set_ylabel('공매도 잔고수량', fontsize=14)   #y2축 설정



lines= line3 + line4
labels = [l.get_label() for l in lines]
do1.legend(lines, labels, loc='best',fontsize=14)

plt.show()
# Out:
# Text(0.5, 1.0, 'KB 금융 공매도 수량과 잔고수량')
# Text(0, 0.5, '공매도 수량(전체)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '공매도 잔고수량')

# %%
do.savefig('KB금융 공매도 수량(시각화).png')

# %%
df2=pd.read_csv("LG 생활건강 공매도_금액.csv",index_col='일자')

# %%
df2.index = pd.to_datetime(df2.index)

# %%
df3=pd.read_csv("LG 생활건강 공매도_수량.csv",index_col='일자')

# %%
df3.index = pd.to_datetime(df2.index)

# %%
df4=pd.read_csv("LG화학 공매도_금액.csv",index_col='일자')

# %%
df4.index = pd.to_datetime(df4.index)

# %%
df5=pd.read_csv("LG화학 공매도_수량.csv",index_col='일자')

# %%
df5.index = pd.to_datetime(df4.index)

# %%
df6=pd.read_csv("NAVER 공매도_금액.csv",index_col='일자')

# %%
df6.index =  pd.to_datetime(df4.index)

# %%
df7=pd.read_csv("NAVER 공매도_수량.csv",index_col='일자')

# %%
df7.index =  pd.to_datetime(df4.index)

# %%
df8=pd.read_csv("SK텔레콤 공매도_금액.csv",index_col='일자')

# %%
df8.index =  pd.to_datetime(df4.index)

# %%
df9=pd.read_csv("SK텔레콤 공매도_수량.csv",index_col='일자')

# %%
df9.index =  pd.to_datetime(df4.index)

# %%
df10=pd.read_csv("삼성물산 공매도_금액.csv",index_col='일자')

# %%
df10.index =  pd.to_datetime(df4.index)

# %%
df11=pd.read_csv("삼성물산 공매도_수량.csv",index_col='일자')

# %%
df11.index =  pd.to_datetime(df4.index)

# %%
df12=pd.read_csv("삼성바이오로직스 공매도_금액.csv",index_col='일자')

# %%
df12.index = pd.to_datetime(df12.index)

# %%
df13=pd.read_csv("삼성바이오로직스 공매도_수량.csv",index_col='일자')

# %%
df13.index = pd.to_datetime(df12.index)

# %%
df14=pd.read_csv("삼성전자 공매도_금액.csv",index_col='일자')

# %%
df14.index = pd.to_datetime(df14.index)

# %%
df15=pd.read_csv("삼성전자 공매도_수량.csv",index_col='일자')

# %%
df15.index = pd.to_datetime(df14.index)

# %%
df16=pd.read_csv("포스코케미칼 공매도_금액.csv",index_col='일자')

# %%
df16.index = pd.to_datetime(df16.index)

# %%
df17=pd.read_csv("포스코케미칼 공매도_수량.csv",index_col='일자')

# %%
df17.index = pd.to_datetime(df16.index)

# %%
df18=pd.read_csv("한국전력 공매도_금액.csv",index_col='일자')

# %%
df18.index = pd.to_datetime(df18.index)

# %%
df19=pd.read_csv("한국전력 공매도_수량.csv",index_col='일자')

# %%
df19.index = pd.to_datetime(df18.index)

# %%
df20=pd.read_csv("현대모비스 공매도_금액.csv",index_col='일자')

# %%
df20.index = pd.to_datetime(df20.index)

# %%
df21=pd.read_csv("현대모비스 공매도_수량.csv",index_col='일자')

# %%
df21.index = pd.to_datetime(df20.index)

# %%
df22=pd.read_csv("현대차 공매도_금액.csv",index_col='일자')

# %%
df22.index = pd.to_datetime(df20.index)

# %%
df23=pd.read_csv("현대차 공매도_수량.csv",index_col='일자')

# %%
df22.index = pd.to_datetime(df20.index)

# %%
do3 = plt.figure(figsize=(20, 12)) # 차트 생성 및 사이즈 설정
do4 = do3.add_subplot(6,4,1) # subplot 생성
do5 = do4.twinx()
do6 = do3.add_subplot(6,4,2) # subplot 생성
do7 = do6.twinx()
do8 = do3.add_subplot(6,4,3) # subplot 생성
do9 = do8.twinx()
do10 = do3.add_subplot(6,4,4) # subplot 생성
do11 = do10.twinx()
do12 = do3.add_subplot(6,4,5) # subplot 생성
do13 = do12.twinx()
do14 = do3.add_subplot(6,4,6) # subplot 생성
do15 = do14.twinx()
do16 = do3.add_subplot(6,4,7) # subplot 생성
do17 = do16.twinx()
do18 = do3.add_subplot(6,4,8) # subplot 생성
do19 = do18.twinx()
do20 = do3.add_subplot(6,4,9) # subplot 생성
do21 = do20.twinx()
do22 = do3.add_subplot(6,4,10) # subplot 생성
do23 = do22.twinx()
do24 = do3.add_subplot(6,4,11) # subplot 생성
do25 = do24.twinx()
do26 = do3.add_subplot(6,4,12) # subplot 생성
do27 = do26.twinx()
do28 = do3.add_subplot(6,4,13) # subplot 생성
do29 = do28.twinx()
do30 = do3.add_subplot(6,4,14) # subplot 생성
do31 = do30.twinx()
do32 = do3.add_subplot(6,4,15) # subplot 생성
do33 = do32.twinx()
do34 = do3.add_subplot(6,4,16) # subplot 생성
do35 = do34.twinx()
do36 = do3.add_subplot(6,4,17) # subplot 생성
do37 = do36.twinx()
do38 = do3.add_subplot(6,4,18) # subplot 생성
do39 = do38.twinx()
do40 = do3.add_subplot(6,4,19) # subplot 생성
do41 = do40.twinx()
do42 = do3.add_subplot(6,4,20) # subplot 생성
do43 = do42.twinx()
do44 = do3.add_subplot(6,4,21) # subplot 생성
do45 = do44.twinx()
do46 = do3.add_subplot(6,4,22) # subplot 생성
do47 = do46.twinx()
do48 = do3.add_subplot(6,4,23) # subplot 생성
do49 = do48.twinx()
do50 = do3.add_subplot(6,4,24) # subplot 생성
do51 = do50.twinx()



line5= do4.plot(df['공매도 금액(전체)'], label='전체금액(100억)', color='b')
line6= do5.plot(df['공매도 금액(잔고금액)'],label='잔고금액(1000억)', color='r')
line7= do6.plot(df1['공매도 수량(전체)'], label='전체수량(25만)', color='b')
line8= do7.plot(df1['공매도 수량(잔고수량)'],label='잔고수량(200만)', color='r')
line9= do8.plot(df2['공매도 금액(전체)'], label='전체금액(100억)', color='b')
line10= do9.plot(df2['공매도 금액(잔고금액)'],label='잔고금액(1000억)', color='r')
line11= do10.plot(df3['공매도 수량(전체)'],label='전체수량(1만)', color='b')
line12= do11.plot(df3['공매도 수량(잔고수량)'],label='잔고수량(10만)', color='r')
line13= do12.plot(df4['공매도 금액(전체)'], label='전체금액(100억)', color='b')
line14= do13.plot(df4['공매도 금액(잔고금액)'],label='잔고금액(1000억)', color='r')
line15= do14.plot(df5['공매도 수량(전체)'],label='전체수량(5만)', color='b')
line16= do15.plot(df5['공매도 수량(잔고수량)'],label='잔고수량(25만)', color='r')
line17= do16.plot(df6['공매도 금액(전체)'], label='전체금액(100억)', color='b')
line18= do17.plot(df6['공매도 금액(잔고금액)'],label='잔고금액(1000억)', color='r')
line19= do18.plot(df7['공매도 수량(전체)'],label='전체수량(10만)', color='b')
line20= do19.plot(df7['공매도 수량(잔고수량)'],label='잔고수량(100만)', color='r')
line21= do20.plot(df8['공매도 금액(전체)'], label='전체금액(50억)', color='b')
line22= do21.plot(df8['공매도 금액(잔고금액)'],label='잔고금액(200억)', color='r')
line23= do22.plot(df9['공매도 수량(전체)'],label='전체수량(2만5천)', color='b')
line24= do23.plot(df9['공매도 수량(잔고수량)'],label='잔고수량(10만)', color='r')
line25= do24.plot(df10['공매도 금액(전체)'], label='전체금액(100억)', color='b')
line26= do25.plot(df10['공매도 금액(잔고금액)'],label='잔고금액(1000억)', color='r')
line27= do26.plot(df11['공매도 수량(전체)'],label='전체수량(2만5천)', color='b')
line28= do27.plot(df11['공매도 수량(잔고수량)'],label='잔고수량(10만)', color='r')
line29= do28.plot(df12['공매도 금액(전체)'], label='전체금액(25억)', color='b')
line30= do29.plot(df12['공매도 금액(잔고금액)'],label='잔고금액(250억)', color='r')
line31= do30.plot(df13['공매도 수량(전체)'],label='전체수량(20만)', color='b')
line32= do31.plot(df13['공매도 수량(잔고수량)'],label='잔고수량(100만)', color='r')
line33= do32.plot(df14['공매도 금액(전체)'], label='전체금액(1000억)', color='b')
line34= do33.plot(df14['공매도 금액(잔고금액)'],label='잔고금액(1조)', color='r')
line35= do34.plot(df15['공매도 수량(전체)'],label='전체수량(200만)', color='b')
line36= do35.plot(df15['공매도 수량(잔고수량)'],label='잔고수량(500만)', color='r')
line37= do36.plot(df16['공매도 금액(전체)'], label='전체금액(100억)', color='b')
line38= do37.plot(df16['공매도 금액(잔고금액)'],label='잔고금액(1000억)', color='r')
line39= do38.plot(df17['공매도 수량(전체)'],label='전체수량(20만)', color='b')
line40= do39.plot(df17['공매도 수량(잔고수량)'],label='잔고수량(100만)', color='r')
line41= do40.plot(df18['공매도 금액(전체)'], label='전체금액(100억)', color='b')
line42= do41.plot(df18['공매도 금액(잔고금액)'],label='잔고금액(200억)', color='r')
line43= do42.plot(df19['공매도 수량(전체)'],label='전체수량(20만)', color='b')
line44= do43.plot(df19['공매도 수량(잔고수량)'],label='잔고수량(50만)', color='r')
line45= do44.plot(df20['공매도 금액(전체)'], label='전체금액(200억)', color='b')
line46= do45.plot(df20['공매도 금액(잔고금액)'],label='잔고금액(2000억)', color='r')
line47= do46.plot(df21['공매도 수량(전체)'],label='전체수량(10만)', color='b')
line48= do47.plot(df21['공매도 수량(잔고수량)'],label='잔고수량(100만)', color='r')
line49= do48.plot(df22['공매도 금액(전체)'], label='전체금액(200억)', color='b')
line50= do49.plot(df22['공매도 금액(잔고금액)'],label='잔고금액(2500억)', color='r')
line51= do50.plot(df23['공매도 수량(전체)'],label='전체수량(20만)', color='b')
line52= do51.plot(df23['공매도 수량(잔고수량)'],label='잔고수량(200만)', color='r')




do4.set_title('KB 금융 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do4.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do4.set_xlabel('Date', fontsize=14) # y축 설정
do5.set_ylabel('잔고금액(\)', fontsize=14) 
do6.set_title('KB 금융 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do6.set_ylabel('공매도 수량(전체)', fontsize=14) # x축 설정
do6.set_xlabel('Date', fontsize=14) # y1축 설정
do7.set_ylabel('공매도 잔고수량', fontsize=14) 
do8.set_title('LG생활건강 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do8.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do8.set_xlabel('Date', fontsize=14) # y축 설정
do9.set_ylabel('잔고금액(\)', fontsize=14) 
do10.set_title('LG생활건강 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do10.set_ylabel('공매도 수량(전체)', fontsize=14) # x축 설정
do10.set_xlabel('Date', fontsize=14) # y축 설정
do11.set_ylabel('공매도 잔고수량', fontsize=14) 
do12.set_title('LG화학 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do12.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do12.set_xlabel('Date', fontsize=14) # y축 설정
do13.set_ylabel('잔고금액(\)', fontsize=14) 
do14.set_title('LG화학 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do14.set_ylabel('공매도 수량(전체)', fontsize=14) # x축 설정
do14.set_xlabel('Date', fontsize=14) # y축 설정
do15.set_ylabel('공매도 잔고수량', fontsize=14) 
do16.set_title('NAVER 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do16.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do16.set_xlabel('Date', fontsize=14) # y축 설정
do17.set_ylabel('잔고금액(\)', fontsize=14) 
do18.set_title('NAVER 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do18.set_ylabel('공매도 수량(전체)', fontsize=14) # x축 설정
do18.set_xlabel('Date', fontsize=14) # y축 설정
do19.set_ylabel('공매도 잔고수량', fontsize=14)
do20.set_title('SK텔레콤 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do20.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do20.set_xlabel('Date', fontsize=14) # y축 설정
do21.set_ylabel('잔고금액(\)', fontsize=14)
do22.set_title('SK텔레콤 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do22.set_ylabel('공매도 수량(전체))', fontsize=14) # x축 설정
do22.set_xlabel('Date', fontsize=14) # y축 설정
do23.set_ylabel('공매도 잔고수량', fontsize=14)
do24.set_title('삼성물산 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do24.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do24.set_xlabel('Date', fontsize=14) # y축 설정
do25.set_ylabel('잔고금액(\)', fontsize=14)
do26.set_title('삼성물산 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do26.set_ylabel('공매도 수량(전체))', fontsize=14) # x축 설정
do26.set_xlabel('Date', fontsize=14) # y축 설정
do27.set_ylabel('공매도 잔고수량', fontsize=14)
do28.set_title('삼성바이오로직스 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do28.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do28.set_xlabel('Date', fontsize=14) # y축 설정
do29.set_ylabel('잔고금액(\)', fontsize=14)
do30.set_title('삼성바이오로직스 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do30.set_ylabel('공매도 수량(전체))', fontsize=14) # x축 설정
do30.set_xlabel('Date', fontsize=14) # y축 설정
do31.set_ylabel('공매도 잔고수량', fontsize=14)
do32.set_title('삼성전자 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do32.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do32.set_xlabel('Date', fontsize=14) # y축 설정
do33.set_ylabel('잔고금액(\)', fontsize=14)
do34.set_title('삼성전자 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do34.set_ylabel('공매도 수량(전체))', fontsize=14) # x축 설정
do34.set_xlabel('Date', fontsize=14) # y축 설정
do35.set_ylabel('공매도 잔고수량', fontsize=14)
do36.set_title('포스코케미칼 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do36.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do36.set_xlabel('Date', fontsize=14) # y축 설정
do37.set_ylabel('잔고금액(\)', fontsize=14)
do38.set_title('포스코케미칼 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do38.set_ylabel('공매도수량(전체)', fontsize=14) # x축 설정
do38.set_xlabel('Date', fontsize=14) # y축 설정
do39.set_ylabel('공매도 잔고수량', fontsize=14)
do40.set_title('한국전력 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do40.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do40.set_xlabel('Date', fontsize=14) # y축 설정
do41.set_ylabel('잔고금액(\)', fontsize=14)
do42.set_title('한국전력 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do42.set_ylabel('공매도수량(전체)', fontsize=14) # x축 설정
do42.set_xlabel('Date', fontsize=14) # y축 설정
do43.set_ylabel('공매도 잔고수량', fontsize=14)
do44.set_title('현대모비스 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do44.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do44.set_xlabel('Date', fontsize=14) # y축 설정
do45.set_ylabel('잔고금액(\)', fontsize=14)
do46.set_title('현대모비스 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do46.set_ylabel('공매도수량(전체)', fontsize=14) # x축 설정
do46.set_xlabel('Date', fontsize=14) # y축 설정
do47.set_ylabel('공매도 잔고수량', fontsize=14)
do48.set_title('현대차 공매도 금액과 잔고금액', fontsize=12) # 타이틀 설정
do48.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
do48.set_xlabel('Date', fontsize=14) # y축 설정
do49.set_ylabel('잔고금액(\)', fontsize=14)
do50.set_title('현대차 공매도 수량과 잔고수량', fontsize=12) # 타이틀 설정
do50.set_ylabel('공매도수량(전체)', fontsize=14) # x축 설정
do50.set_xlabel('Date', fontsize=14) # y축 설정
do51.set_ylabel('공매도 잔고수량', fontsize=14)

lines= line5 + line6
labels = [l.get_label() for l in lines]
do4.legend(lines, labels, loc='best',fontsize=12)

liness= line7 + line8
labels = [l.get_label() for l in liness]
do6.legend(liness, labels, loc='best',fontsize=12)

linesss= line9 + line10
labels = [l.get_label() for l in linesss]
do8.legend(linesss, labels, loc='best',fontsize=12)

linessss= line11+ line12
labels = [l.get_label() for l in linessss]
do10.legend(linessss, labels, loc='best',fontsize=12)

linesssss= line13+ line14
labels = [l.get_label() for l in linesssss]
do12.legend(linesssss, labels, loc='best',fontsize=12)

linessssss= line15+ line16
labels = [l.get_label() for l in linessssss]
do14.legend(linessssss, labels, loc='best',fontsize=12)

bo= line17+ line18
labels = [l.get_label() for l in bo]
do16.legend(bo, labels, loc='best',fontsize=12)

bo1= line19+ line20
labels = [l.get_label() for l in bo1]
do18.legend(bo1, labels, loc='best',fontsize=12)

bo2= line21+ line22
labels = [l.get_label() for l in bo2]
do20.legend(bo2, labels, loc='best',fontsize=12)

bo3= line23+ line24
labels = [l.get_label() for l in bo3]
do22.legend(bo3, labels, loc='best',fontsize=12)


bo4= line25+ line26
labels = [l.get_label() for l in bo4]
do24.legend(bo4, labels, loc='best',fontsize=12)

bo5= line27+ line28
labels = [l.get_label() for l in bo5]
do26.legend(bo5, labels, loc='best',fontsize=12)


bo6= line29+ line30
labels = [l.get_label() for l in bo6]
do28.legend(bo6, labels, loc='best',fontsize=12)

bo7= line31+ line32
labels = [l.get_label() for l in bo7]
do30.legend(bo7, labels, loc='best',fontsize=12)

bo8= line33+ line34
labels = [l.get_label() for l in bo8]
do32.legend(bo8, labels, loc='best',fontsize=12)

bo9= line35+ line36
labels = [l.get_label() for l in bo9]
do34.legend(bo9, labels, loc='best',fontsize=12)


bo10= line37+ line38
labels = [l.get_label() for l in bo10]
do36.legend(bo10, labels, loc='best',fontsize=12)

bo11= line39+ line40
labels = [l.get_label() for l in bo11]
do38.legend(bo11, labels, loc='best',fontsize=12)

bo12= line41+ line42
labels = [l.get_label() for l in bo12]
do40.legend(bo12, labels, loc='best',fontsize=12)

bo13= line43+ line44
labels = [l.get_label() for l in bo13]
do42.legend(bo13, labels, loc='best',fontsize=12)

bo14= line45+ line46
labels = [l.get_label() for l in bo14]
do44.legend(bo14, labels, loc='best',fontsize=12)

bo15= line47+ line48
labels = [l.get_label() for l in bo15]
do46.legend(bo15, labels, loc='best',fontsize=12)

bo16= line49+ line50
labels = [l.get_label() for l in bo16]
do48.legend(bo16, labels, loc='best',fontsize=12)

bo17= line51+ line52
labels = [l.get_label() for l in bo17]
do50.legend(bo17, labels, loc='best',fontsize=12)

do3.tight_layout()
plt.show()
# Out:
# Text(0.5, 1.0, 'KB 금융 공매도 금액과 잔고금액')
# Text(0, 0.5, '전체 거래대금(\\)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '잔고금액(\\)')
# Text(0.5, 1.0, 'KB 금융 공매도 수량과 잔고수량')
# Text(0, 0.5, '공매도 수량(전체)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '공매도 잔고수량')
# Text(0.5, 1.0, 'LG생활건강 공매도 금액과 잔고금액')
# Text(0, 0.5, '전체 거래대금(\\)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '잔고금액(\\)')
# Text(0.5, 1.0, 'LG생활건강 공매도 수량과 잔고수량')
# Text(0, 0.5, '공매도 수량(전체)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '공매도 잔고수량')
# Text(0.5, 1.0, 'LG화학 공매도 금액과 잔고금액')
# Text(0, 0.5, '전체 거래대금(\\)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '잔고금액(\\)')
# Text(0.5, 1.0, 'LG화학 공매도 수량과 잔고수량')
# Text(0, 0.5, '공매도 수량(전체)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '공매도 잔고수량')
# Text(0.5, 1.0, 'NAVER 공매도 금액과 잔고금액')
# Text(0, 0.5, '전체 거래대금(\\)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '잔고금액(\\)')
# Text(0.5, 1.0, 'NAVER 공매도 수량과 잔고수량')
# Text(0, 0.5, '공매도 수량(전체)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '공매도 잔고수량')
# Text(0.5, 1.0, 'SK텔레콤 공매도 금액과 잔고금액')
# ...

# %%
do3.savefig('공매도 종합 데이터(시각화).png')
