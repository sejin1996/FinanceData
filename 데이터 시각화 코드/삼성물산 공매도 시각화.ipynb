# %%
import matplotlib.pyplot as plt
# %matplotlib inline


import pandas as pd
import numpy as np


from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
df=pd.read_csv("../삼성물산 공매도.csv",index_col='일자')

df.head()
# Out:
#             공매도 수량(전체)  공매도 수량(잔고수량)  공매도 금액(전체)  공매도 금액(잔고금액)
# 일자
# 2021-03-31         820         41940   102522000  5.221530e+09
# 2021-03-30          63         32534     7938000  4.099284e+09
# 2021-03-29        1027         36398   125503000  4.458755e+09
# 2021-03-26         397         32374    48926000  3.982002e+09
# 2021-03-25         232         42749    28652000  5.279502e+09

# %%
df1=df.iloc[:,2:4]

# %%
df1.to_csv("삼성물산 공매도_금액.csv",mode="w")

# %%
df2=df.iloc[:,0:2]

# %%
df2.to_csv("삼성물산 공매도_수량.csv",mode="w")

# %%
df3=pd.read_csv("삼성물산 공매도_금액.csv",index_col='일자')

# %%
df3.head()
# Out:
#             공매도 금액(전체)  공매도 금액(잔고금액)
# 일자
# 2021-03-31   102522000  5.221530e+09
# 2021-03-30     7938000  4.099284e+09
# 2021-03-29   125503000  4.458755e+09
# 2021-03-26    48926000  3.982002e+09
# 2021-03-25    28652000  5.279502e+09

# %%
df3.index = pd.to_datetime(df3.index)

fig = plt.figure(figsize=(20, 12)) # 차트 생성 및 사이즈 설정
ax = fig.add_subplot(1,1,1) # subplot 생성
ax2 = ax.twinx()


line1=ax.plot(df3['공매도 금액(전체)'], label='전체금액(50억)', color='b')
line2=ax2.plot(df3['공매도 금액(잔고금액)'],label='잔고금액(250억)', color='r')


ax.set_title('삼성물산 공매도 금액과 잔고금액', fontsize=20) # 타이틀 설정
ax.set_ylabel('전체 거래대금(\)', fontsize=14) # x축 설정
ax.set_xlabel('Date', fontsize=14) # y1축 설정
ax2.set_ylabel('잔고금액(\)', fontsize=14)   #y2축 설정



lines= line1 + line2
labels = [l.get_label() for l in lines]
ax.legend(lines, labels, loc='best',fontsize=14)

plt.show()
# Out:
# Text(0.5, 1.0, '삼성물산 공매도 금액과 잔고금액')
# Text(0, 0.5, '전체 거래대금(\\)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '잔고금액(\\)')

# %%
fig.savefig('삼성물산 공매도 금액(시각화).png')

# %%
df4=pd.read_csv("삼성물산 공매도_수량.csv",index_col='일자')

# %%
df4.head()
# Out:
#             공매도 수량(전체)  공매도 수량(잔고수량)
# 일자
# 2021-03-31         820         41940
# 2021-03-30          63         32534
# 2021-03-29        1027         36398
# 2021-03-26         397         32374
# 2021-03-25         232         42749

# %%
df4.index = pd.to_datetime(df4.index)

do = plt.figure(figsize=(20, 12)) # 차트 생성 및 사이즈 설정
do1 = do.add_subplot(1,1,1) # subplot 생성
do2 = do1.twinx()


line3=do1.plot(df4['공매도 수량(전체)'], label='전체수량(10만)', color='b')
line4=do2.plot(df4['공매도 수량(잔고수량)'],label='잔고수량(20만)', color='r')


do1.set_title('삼성물산 수량과 잔고수량', fontsize=20) # 타이틀 설정
do1.set_ylabel('공매도 수량(전체)', fontsize=14) # x축 설정
do1.set_xlabel('Date', fontsize=14) # y1축 설정
do2.set_ylabel('공매도 잔고수량', fontsize=14)   #y2축 설정



lines= line3 + line4
labels = [l.get_label() for l in lines]
do1.legend(lines, labels, loc='best',fontsize=14)

plt.show()
# Out:
# Text(0.5, 1.0, '삼성물산 수량과 잔고수량')
# Text(0, 0.5, '공매도 수량(전체)')
# Text(0.5, 0, 'Date')
# Text(0, 0.5, '공매도 잔고수량')

# %%
do.savefig('삼성물산 공매도 수량(시각화).png')
